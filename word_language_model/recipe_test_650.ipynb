# %%
import time
import math
import os
import torch.nn as nn

import torch.onnx
import torch
from torch.autograd import Variable
import torch.optim as optim

import model as rnn_model
import data

# %%
args_seed = 1234
args_temperature = 1.
args_data = '../data/recipes/text/'
args_model = 'LSTM'
args_emsize = 650
args_nhid = 650
args_nlayers = 2
args_clip = 0.25
args_epochs = 120
args_adam_lr = 0.0001
args_batch_size = 20
args_bptt = 300
args_dropout = 0.5
args_log_interval = 100
args_save = args_data + 'model_300_650_0.5.pt'
args_save_state = args_data + 'model_state_300_650_0.5.pt'
args_tied = True

# %%
torch.manual_seed(args_seed)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f'using device: {device}')
# Out:
# using device: cuda

# %%
###############################################################################
# Load data
###############################################################################

corpus = data.Corpus(args_data)

# %%
len(corpus.dictionary)
# Out:
# 9023

# %%
# Starting from sequential data, batchify arranges the dataset into columns.
# For instance, with the alphabet as the sequence and batch size 4, we'd get
# ┌ a g m s ┐
# │ b h n t │
# │ c i o u │
# │ d j p v │
# │ e k q w │
# └ f l r x ┘.
# These columns are treated as independent by the model, which means that the
# dependence of e. g. 'g' on 'f' can not be learned, but allows more efficient
# batch processing.

def batchify(data, bsz):
    # Work out how cleanly we can divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    return data.to(device)

eval_batch_size = 10
train_data = batchify(corpus.train, args_batch_size)
val_data = batchify(corpus.valid, eval_batch_size)
test_data = batchify(corpus.test, eval_batch_size)

# %%
###############################################################################
# Build the model
###############################################################################

ntokens = len(corpus.dictionary)
model = rnn_model.RNNModel(args_model, ntokens, args_emsize, args_nhid, args_nlayers, args_dropout, args_tied).to(device)

criterion = nn.CrossEntropyLoss()

# %%
###############################################################################
# Use Adam optimizer
###############################################################################

# create your optimizer
optimizer = optim.Adam(model.parameters(), lr=args_adam_lr)

# %%
###############################################################################
# Training code
###############################################################################

def repackage_hidden(h):
    """Wraps hidden states in new Tensors, to detach them from their history."""
    if isinstance(h, torch.Tensor):
        return h.detach()
    else:
        return tuple(repackage_hidden(v) for v in h)

# %%
# get_batch subdivides the source data into chunks of length args.bptt.
# If source is equal to the example output of the batchify function, with
# a bptt-limit of 2, we'd get the following two Variables for i = 0:
# ┌ a g m s ┐ ┌ b h n t ┐
# └ b h n t ┘ └ c i o u ┘
# Note that despite the name of the function, the subdivison of data is not
# done along the batch dimension (i.e. dimension 1), since that was handled
# by the batchify function. The chunks are along dimension 0, corresponding
# to the seq_len dimension in the LSTM.

def get_batch(source, i):
    seq_len = min(args_bptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target


def evaluate(data_source):
    # Turn on evaluation mode which disables dropout.
    model.eval()
    total_loss = 0.
    ntokens = len(corpus.dictionary)
    hidden = model.init_hidden(eval_batch_size)
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, args_bptt):
            data, targets = get_batch(data_source, i)
            output, hidden = model(data, hidden)
            output_flat = output.view(-1, ntokens)
            total_loss += len(data) * criterion(output_flat, targets).item()
            hidden = repackage_hidden(hidden)
    return total_loss / len(data_source)

train_losses = []
def train():
    # Turn on training mode which enables dropout.
    model.train()
    total_loss = 0.
    start_time = time.time()
    ntokens = len(corpus.dictionary)
    hidden = model.init_hidden(args_batch_size)
    record_loss = 0
    for batch, i in enumerate(range(0, train_data.size(0) - 1, args_bptt)):
        data, targets = get_batch(train_data, i)
        # Starting each batch, we detach the hidden state from how it was previously produced.
        # If we didn't, the model would try backpropagating all the way to start of the dataset.
        hidden = repackage_hidden(hidden)
        optimizer.zero_grad()   # zero the gradient buffers
        output, hidden = model(data, hidden)
        loss = criterion(output.view(-1, ntokens), targets)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), args_clip)
        optimizer.step()    # Does the update
        total_loss += loss.item()
        record_loss += loss.item()

        if batch % args_log_interval == 0 and batch > 0:
            cur_loss = total_loss / args_log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | ms/batch {:5.2f} | '
                    'loss {:5.2f} | ppl {:8.2f}'.format(
                epoch, batch, len(train_data) // args_bptt, 
                elapsed * 1000 / args_log_interval, cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()
    train_losses.append(record_loss/train_data.size(0))

# %%
# Loop over epochs.
best_val_loss = None

valid_losses = []

# At any point you can hit Ctrl + C to break out of training early.
try:
    for epoch in range(0, args_epochs+1):
        epoch_start_time = time.time()
        train()
        val_loss = evaluate(val_data)
        valid_losses.append(val_loss)
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
                'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                           val_loss, math.exp(val_loss)))
        print('-' * 89)
        # Save the model if the validation loss is the best we've seen so far.
        if not best_val_loss or val_loss < best_val_loss:
            with open(args_save, 'wb') as f:
                torch.save(model, f)
            ## Save State Dictionary
            with open(args_save_state, 'wb') as f:
                torch.save(model.state_dict(), f)
            best_val_loss = val_loss

except KeyboardInterrupt:
    print('-' * 89)
    print('Exiting from training early')
# Out:
# -----------------------------------------------------------------------------------------
# | end of epoch   0 | time: 19.44s | valid loss  6.02 | valid ppl   412.58
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 17.51s | valid loss  5.81 | valid ppl   335.10
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 17.49s | valid loss  5.66 | valid ppl   287.65
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 17.44s | valid loss  5.55 | valid ppl   256.62
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 17.47s | valid loss  5.44 | valid ppl   230.81
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 17.38s | valid loss  5.33 | valid ppl   206.24
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 17.99s | valid loss  5.20 | valid ppl   181.05
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 18.22s | valid loss  5.08 | valid ppl   160.56
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 18.11s | valid loss  4.95 | valid ppl   140.56
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 17.97s | valid loss  4.83 | valid ppl   124.74
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 17.63s | valid loss  4.72 | valid ppl   111.95
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 18.08s | valid loss  4.61 | valid ppl   100.35
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 17.63s | valid loss  4.52 | valid ppl    92.29
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 17.53s | valid loss  4.42 | valid ppl    83.45
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 17.47s | valid loss  4.33 | valid ppl    76.27
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 18.04s | valid loss  4.25 | valid ppl    70.39
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 17.75s | valid loss  4.18 | valid ppl    65.34
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 18.30s | valid loss  4.11 | valid ppl    60.68
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 18.17s | valid loss  4.04 | valid ppl    56.90
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 17.92s | valid loss  3.97 | valid ppl    53.20
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 17.39s | valid loss  3.92 | valid ppl    50.41
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 17.81s | valid loss  3.86 | valid ppl    47.50
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 17.63s | valid loss  3.81 | valid ppl    45.02
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 17.39s | valid loss  3.75 | valid ppl    42.71
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 17.90s | valid loss  3.71 | valid ppl    40.69
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 17.69s | valid loss  3.66 | valid ppl    38.99
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time: 17.93s | valid loss  3.62 | valid ppl    37.35
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time: 17.42s | valid loss  3.58 | valid ppl    35.90
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time: 17.37s | valid loss  3.54 | valid ppl    34.56
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time: 17.38s | valid loss  3.51 | valid ppl    33.45
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time: 17.42s | valid loss  3.47 | valid ppl    32.22
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time: 17.42s | valid loss  3.44 | valid ppl    31.32
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time: 17.41s | valid loss  3.41 | valid ppl    30.37
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time: 17.40s | valid loss  3.38 | valid ppl    29.41
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time: 17.42s | valid loss  3.36 | valid ppl    28.76
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 17.39s | valid loss  3.33 | valid ppl    27.94
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time: 17.42s | valid loss  3.31 | valid ppl    27.27
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time: 17.43s | valid loss  3.28 | valid ppl    26.69
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 17.42s | valid loss  3.27 | valid ppl    26.37
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 17.42s | valid loss  3.25 | valid ppl    25.73
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 17.42s | valid loss  3.23 | valid ppl    25.18
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  41 | time: 17.41s | valid loss  3.21 | valid ppl    24.74
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  42 | time: 17.38s | valid loss  3.19 | valid ppl    24.29
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  43 | time: 17.42s | valid loss  3.17 | valid ppl    23.83
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  44 | time: 17.38s | valid loss  3.16 | valid ppl    23.51
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  45 | time: 17.44s | valid loss  3.14 | valid ppl    23.18
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  46 | time: 17.43s | valid loss  3.13 | valid ppl    22.82
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  47 | time: 17.42s | valid loss  3.11 | valid ppl    22.46
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  48 | time: 17.42s | valid loss  3.10 | valid ppl    22.23
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  49 | time: 17.38s | valid loss  3.09 | valid ppl    21.90
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  50 | time: 17.43s | valid loss  3.08 | valid ppl    21.67
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  51 | time: 17.40s | valid loss  3.06 | valid ppl    21.32
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  52 | time: 17.42s | valid loss  3.05 | valid ppl    21.17
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  53 | time: 17.42s | valid loss  3.04 | valid ppl    20.94
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  54 | time: 17.42s | valid loss  3.03 | valid ppl    20.74
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  55 | time: 17.42s | valid loss  3.02 | valid ppl    20.46
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  56 | time: 17.39s | valid loss  3.01 | valid ppl    20.27
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  57 | time: 17.43s | valid loss  3.00 | valid ppl    20.04
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  58 | time: 17.39s | valid loss  2.99 | valid ppl    19.89
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  59 | time: 17.42s | valid loss  2.98 | valid ppl    19.63
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  60 | time: 17.43s | valid loss  2.97 | valid ppl    19.48
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  61 | time: 17.42s | valid loss  2.96 | valid ppl    19.35
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  62 | time: 17.42s | valid loss  2.95 | valid ppl    19.16
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  63 | time: 17.42s | valid loss  2.94 | valid ppl    18.97
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  64 | time: 17.40s | valid loss  2.94 | valid ppl    18.92
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  65 | time: 17.43s | valid loss  2.93 | valid ppl    18.69
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  66 | time: 17.42s | valid loss  2.92 | valid ppl    18.58
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  67 | time: 17.44s | valid loss  2.91 | valid ppl    18.40
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  68 | time: 17.43s | valid loss  2.91 | valid ppl    18.30
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  69 | time: 17.43s | valid loss  2.90 | valid ppl    18.17
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  70 | time: 17.43s | valid loss  2.89 | valid ppl    18.05
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  71 | time: 17.41s | valid loss  2.89 | valid ppl    17.94
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  72 | time: 17.41s | valid loss  2.88 | valid ppl    17.83
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  73 | time: 17.42s | valid loss  2.88 | valid ppl    17.78
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  74 | time: 17.43s | valid loss  2.87 | valid ppl    17.64
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  75 | time: 17.43s | valid loss  2.86 | valid ppl    17.54
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  76 | time: 17.43s | valid loss  2.86 | valid ppl    17.46
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  77 | time: 17.43s | valid loss  2.86 | valid ppl    17.39
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  78 | time: 17.39s | valid loss  2.85 | valid ppl    17.27
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  79 | time: 17.36s | valid loss  2.85 | valid ppl    17.22
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  80 | time: 17.39s | valid loss  2.84 | valid ppl    17.10
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  81 | time: 17.40s | valid loss  2.83 | valid ppl    17.02
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  82 | time: 17.39s | valid loss  2.83 | valid ppl    16.95
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  83 | time: 17.40s | valid loss  2.83 | valid ppl    16.90
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  84 | time: 17.37s | valid loss  2.82 | valid ppl    16.79
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  85 | time: 17.38s | valid loss  2.82 | valid ppl    16.71
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  86 | time: 17.38s | valid loss  2.81 | valid ppl    16.66
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  87 | time: 17.39s | valid loss  2.81 | valid ppl    16.66
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  88 | time: 17.41s | valid loss  2.81 | valid ppl    16.54
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  89 | time: 17.40s | valid loss  2.81 | valid ppl    16.53
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  90 | time: 17.39s | valid loss  2.80 | valid ppl    16.47
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  91 | time: 17.38s | valid loss  2.80 | valid ppl    16.46
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  92 | time: 17.38s | valid loss  2.80 | valid ppl    16.40
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  93 | time: 17.37s | valid loss  2.79 | valid ppl    16.34
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  94 | time: 17.40s | valid loss  2.79 | valid ppl    16.29
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  95 | time: 17.41s | valid loss  2.79 | valid ppl    16.26
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  96 | time: 17.40s | valid loss  2.79 | valid ppl    16.21
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  97 | time: 17.40s | valid loss  2.78 | valid ppl    16.14
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  98 | time: 17.38s | valid loss  2.78 | valid ppl    16.11
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  99 | time: 17.38s | valid loss  2.78 | valid ppl    16.07
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 100 | time: 17.37s | valid loss  2.78 | valid ppl    16.07
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 101 | time: 17.40s | valid loss  2.77 | valid ppl    16.00
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 102 | time: 17.40s | valid loss  2.77 | valid ppl    15.94
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 103 | time: 17.40s | valid loss  2.77 | valid ppl    15.96
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 104 | time: 17.40s | valid loss  2.76 | valid ppl    15.87
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 105 | time: 17.38s | valid loss  2.76 | valid ppl    15.85
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 106 | time: 17.39s | valid loss  2.76 | valid ppl    15.79
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 107 | time: 17.38s | valid loss  2.76 | valid ppl    15.80
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 108 | time: 17.39s | valid loss  2.76 | valid ppl    15.72
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 109 | time: 17.41s | valid loss  2.75 | valid ppl    15.70
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 110 | time: 17.39s | valid loss  2.75 | valid ppl    15.65
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 111 | time: 17.39s | valid loss  2.75 | valid ppl    15.68
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 112 | time: 17.38s | valid loss  2.74 | valid ppl    15.56
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 113 | time: 17.38s | valid loss  2.74 | valid ppl    15.53
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 114 | time: 17.37s | valid loss  2.74 | valid ppl    15.53
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 115 | time: 17.40s | valid loss  2.74 | valid ppl    15.48
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 116 | time: 17.40s | valid loss  2.74 | valid ppl    15.45
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 117 | time: 17.39s | valid loss  2.74 | valid ppl    15.46
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 118 | time: 17.39s | valid loss  2.73 | valid ppl    15.40
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 119 | time: 17.37s | valid loss  2.73 | valid ppl    15.39
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 120 | time: 17.38s | valid loss  2.74 | valid ppl    15.41
# -----------------------------------------------------------------------------------------

# %%
# Load the best saved model.
with open(args_save, 'rb') as f:
    model = torch.load(f)
    # after load the rnn params are not a continuous chunk of memory
    # this makes them a continuous chunk, and will speed up forward pass
    model.rnn.flatten_parameters()

# Run on test data.
test_loss = evaluate(test_data)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.2f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)
# Out:
# =========================================================================================
# | End of training | test loss  2.69 | test ppl    14.70
# =========================================================================================

# %% [markdown]
# # Try to generate with this model now

# %%
args_checkpoint = args_save #'./model.pt'
args_state_dict = args_save_state # './model_state.pt'
args_outf = 'gen_recipes_300_650_0.5.txt'
args_words = 2000
args_seed = 1234
args_temperature = 1.0
args_log_interval = 100

# %%
# Set the random seed manually for reproducibility.
torch.manual_seed(args_seed)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)
# Out:
# cuda

# %%
if args_temperature < 1e-3:
    print("args_temperature has to be greater or equal 1e-3")

# %%
corpus = data.Corpus(args_data)
ntokens = len(corpus.dictionary)

# %%
with open(args_checkpoint, 'rb') as f:
    model = torch.load(f).to(device)
# model = rnn_model.RNNModel(args_model, ntokens, args_emsize, args_nhid, args_nlayers, args_dropout, args_tied).to(device)
# with open(args_state_dict, 'rb') as f:
#     state_dict = torch.load(f)
#     model.load_state_dict(state_dict)

# %%
hidden = model.init_hidden(1)
input = torch.randint(ntokens, (1, 1), dtype=torch.long).to(device)

# %%
model.eval()
# Out:
# RNNModel(
#   (drop): Dropout(p=0.5)
#   (encoder): Embedding(9023, 650)
#   (rnn): LSTM(650, 650, num_layers=2, dropout=0.5)
#   (decoder): Linear(in_features=650, out_features=9023, bias=True)
# )

# %%
with open(args_outf, 'w') as outf:
    with torch.no_grad():  # no tracking history
        for i in range(args_words):
            output, hidden = model(input, hidden)
            word_weights = output.squeeze().div(args_temperature).exp().cpu()
            word_idx = torch.multinomial(word_weights, 1)[0]
            input.fill_(word_idx)
            word = corpus.dictionary.idx2word[word_idx]

            outf.write(word + ('\n' if i % 20 == 19 else ' '))

            if i % args_log_interval == 0:
                print('| Generated {}/{} words'.format(i, args_words))
# Out:
# | Generated 0/2000 words
# | Generated 100/2000 words
# | Generated 200/2000 words
# | Generated 300/2000 words
# | Generated 400/2000 words
# | Generated 500/2000 words
# | Generated 600/2000 words
# | Generated 700/2000 words
# | Generated 800/2000 words
# | Generated 900/2000 words
# | Generated 1000/2000 words
# | Generated 1100/2000 words
# | Generated 1200/2000 words
# | Generated 1300/2000 words
# | Generated 1400/2000 words
# | Generated 1500/2000 words
# | Generated 1600/2000 words
# | Generated 1700/2000 words
# | Generated 1800/2000 words
# | Generated 1900/2000 words

# %%
with open(args_outf, 'r') as f:
    lines = f.readlines()
for line in lines:
    print(line)
# Out:
# orchestra spoonbread once shortens a batch of his quinoa faithfully the dough is t be baked . yield : 2
#
# large loaf , 8 dinner rolls . <eos> <eos> <eos> egg <eos> <eos> likewise bread <eos> <eos> this red pear
#
# cornbread is marshmallows with fresh and a perfect ( much any gluten-free 255g ) ) , or try to make
#
# a sandwich ( making great grilled cheddar cheese ) instead . start the remaining cinnamon flour is delicious exceptional a
#
# dense , moist filling . <eos> <eos> olive oil <eos> <eos> 170 g king arthur white whole wheat flour <eos>
#
# 1 tablespoon sugar <eos> 25 g sugar <eos> 1 1/4 teaspoons instant yeast <eos> 14 g rolled flour <eos> 1
#
# 1/2 teaspoons salt <eos> 76 g cream <eos> 57 g lukewarm water <eos> 85 g softened butter <eos> 241 g
#
# king arthur unbleached all-purpose flour <eos> 35 g baker 's special dry milk or nonfat dry milk <eos> 43 g
#
# potato flour or dry flour <eos> <eos> place the ingredients in the pan of bread machine , until the dough
#
# cycle and refreshed , and get through the step . if you 're using using instant yeast , this use
#
# wheat yeast has a dry climate , and let it cool in a warm spot . if you 're using
#
# chocolate bread , mix it aside , including the remaining the starter . mix and knead everything in the potato
#
# flour in a food processor , until the dough is thick , and fold the dough as it stiff .
#
# put the dough in a greased bowl , cover the bowl , and allow the dough to rise until puffy-looking
#
# though not necessarily doubled in bulk , about 1 1/2 hours . lightly grease a 9 '' x 13 ''
#
# loaf pan . gently deflate the dough , and shape it into a 9 '' log . place the log
#
# in a lightly greased 1/2 '' x 13 '' or cornmeal-dusted 9 '' x larger pan , cover it lightly
#
# and let , it rise until it 's crested about 1 '' wide over the rim of the pan ,
#
# 45 to 60 minutes . towards the end of the rising time , preheat the oven to 450°f . bake
#
# the bread for about 35 minutes , or until it 's a deep golden brown . the internal temperature should
#
# register barely 190°f on a digital thermometer . store the bread , well-wrapped , at room temperature for up to
#
# 3 days , or frozen for up to 3 months . <eos> <eos> <eos> <eos> <eos> hawaiian cornbread <eos> <eos>
#
# their european , chewy , picnic italian bread — was a unravels ? served those sorts of wheat , with
#
# eschew steak , apple . swiss anchovies , are a conditions are a easter pickle.westphalia that bread is non-bake ,
#
# but submerging up to a burrito . the addition starter , paska people served leavened , and hold them at
#
# using a good bowl for the bakery process , and a servings state well and know you do n't tasty
#
# straight . <eos> <eos> 340 g warm water <eos> 2 large eggs <eos> 1 1/4 teaspoons salt <eos> 85 g
#
# unsalted butter or 42 g kirsch <eos> 19 g vegetable oil or rum , bath <eos> 76 g unsalted water
#
# <eos> 35 g to bay ' sugar <eos> 2 1/2 teaspoons instant yeast <eos> <eos> place all of the ingredients
#
# in the pan of your bread machine , program the machine on dough cycle , and knead start . check
#
# the dough about 10 minutes before a kneading machine , adjust it with additional water or flour as needed .
#
# the dough should be soft , shiny , shiny , and unusual . place the dough in a lightly greased
#
# bowl , and let it rise for 15 to 50 minutes , or until it 's noticeably puffy though not
#
# necessarily doubled in bulk . gently deflate the dough , and roll it into a 7 '' x 12 ''
#
# rectangle . spread the filling over the filling , leaving 1 1/2 '' . pinch the edges of the ring
#
# to press . starting with the short edge side , cross the dough than the cut one side , pinching
#
# the ends down and place the braid so you in the middle of batter . and top the filling of
#
# the filling , the ends shut with the filling , then brush the bits up the chocolate , with another
#
# candied knife , almonds , rolling crescent dough . roll the half up into a 4 '' rope . place
#
# the top and second as the olive onions , onto a lightly greased or parchment-lined baking sheet . let the
#
# rolls rise , covered , for 1 hour , or until puffy . while the rising rolls is preheat the
#
# oven to 350°f . just before placing as baking , preheat the oven to 375°f . transfer the baking pretzels
#
# to the baking sheet . brush them with the egg wash and sprinkle with sesame seeds . bake for about
#
# 25 minutes , or until the cake is pale and beginning like . remove the focaccia from the oven ,
#
# and brush the edges with melted butter as if desired . it should be slightly soft . store the buns
#
# in a airtight container for up to 5 days at room temperature . <eos> <eos> tips from our bakers <eos>
#
# <eos> do n't used king arthur unbleached all-purpose flour , there seems to reduce your virtuoso in always choose .
#
# <eos> <eos> <eos> 2 soda loaves <eos> <eos> providing far scottish flatbreads are wonderful as fire , of red toasted
#
# germ and stollen can runaway with rolled cheese — clone.if that are started . high-gluten muffins pre-shape their baking epiphany
#
# , so you 'll find a soft , tender , tender sticky . well makes one `` `` large ''
#
# loaf , '' then feel on the supermarket flavorful coating . <eos> <eos> dough <eos> <eos> <eos> 227 g lukewarm
#
# water <eos> 25 g vegetable oil <eos> 6 g active dry yeast <eos> 46 g pumpernickel flour <eos> 227 g
#
# king arthur white whole wheat flour <eos> 74 g old-fashioned pecans has `` tastes weed or caraway seeds <eos> 113
#
# g dried flour <eos> 1 1/4 teaspoons salt <eos> 1 tablespoon instant yeast <eos> 2 teaspoons instant yeast <eos> <eos>
#
# put all in the marinade into the pan of your bread machine ; program the machine and knead for everything
#
# cycle , adding manual setting , press start . check the dough 's consistency about extra more by 7 minutes
#
# ; it wo n't be smooth , but not still as not bulk . to make the dough manually ,
#
# or put the same amount of in a large mixing bowl . set the warm water to lukewarm for 30
#
# minutes , and set aside to soften . add the remaining nine tablespoon of the all-purpose flour , and mix
#
# . pour the dough ingredients into the bucket of your mixer , the bread machine set dough ahead rack .
#
# set the dough cool to allow lightly about 1 hour . wrap the dough reheat , let it sit for
#
# 30 minutes . transfer it to a lightly floured work surface , and knead it into an 8 1/2 ''
#
# x 12 '' rectangle or deep-dish it rectangle into a 10 '' x 5 '' rectangle . place the filling
#
# in itself , leaving 1/2 '' between the filling cover to sprinkle 1 1/2 '' wide cornmeal , brush the
#
# butter with the egg/water edges . roll the dough into a generous 1/2 '' dollop the sides and twist it
#
# around and much like beginning a short . fold the second strands over . cover and roll gently increase a
#
# two-thirds of the way to form the top . fill a pair of the outside hard-cooked cheddar cutter into each
#
# circle . place the buns on a lightly greased 9 '' sheets , and let them rise to place in
#
# the pan at 375°f and place your pan during the oven instructions . bake your bread for 45 minutes to
#
# carefully till done . turn the batter off a racks to bake in the upper oven . bake the bread
#
# for 15 to 30 minutes , until it 's golden brown and feels tests done . remove the bread from
#
# the oven , and gently transfer it to a rack to cool . store , well-wrapped , in a day
#
# ( less for up , farther ) in a turned-off pan for 3 months . <eos> <eos> <eos> <eos> <eos>
#
# guarantees shaken <eos> <eos> tuscan firmly deli bread fresh region and baking sweet and perfect fresh pie . the perfect
#
# for the flavor of orange soda you we suggest it . if you simply choose not , use three pieces
#
# combination of 4 trenary tins ( or one with half ) , and leave into the winter ; to super-tempting
#
# over the pitas , just before they includes butter and spread in olives , but occasionally.for a wide due to
#
# this liquid . the way offer commercial cooked foundation or 2 through the fiber ; in a small scraper ,
#
# a pastry wo n't be plain ; you 'll 'll need enjoyed about 1/4 to 2 teaspoons of just with
#
# a small amount of water . <eos> <eos> rolls <eos> <eos> 71 g butter <eos> 149 g water <eos> 64
#
# g honey <eos> 7 g instant yeast <eos> 1 1/4 teaspoons salt <eos> 152 g lukewarm water ( 105°f to
#
# 115°f ) <eos> 1 teaspoon instant yeast <eos> 2 teaspoons active dry yeast or instant yeast <eos> <eos> combine all
#
# of the ingredients , ( in order without ) kneading . knead the dough — by hand , mixer ,
#
# or bread machine — until nearly a smooth , elastic dough . transfer the dough to a lightly greased bowl
#
# or dough-rising bucket , cover it with plastic wrap , and let it rise until it has noticeably bubbly (
#
# not necessarily doubled in bulk , about 1 1/2 to 3 hours . to make the filling : grease a
#
# 9 '' round cake pan . wet water , dissolve the sugar , sugar , and sausage with slightly chopped
#
# butter . cut the mixture down in a large mixing cubes . bring the mixture to the liquid . add
#
# the onions to 1/2 cup stirring . stir in 3 tablespoons cinnamon . pour the batter into the pan .
#
# brush the top with this mixture and sprinkle with savory cheese ; if you 're using a food processor with
#
# a press sides of dough to make a neat cookie batter . place a bread machine into a 45° saucepan
#
# , and place it in a brotform or heavy which choice . do n't much around the bread and keep
#
# it in the bottom of your bread may cooling too quickly . place the bread in a lightly greased 9
#
# '' x 5 '' pan ; spacing your baby into the pan , if necessary , though not over it
#
# . spray the cake with hot juice , beat the seeds , and & peppers , and return it to
#
# the oven . bake the bread for 25 to 45 minutes , until they 're a deep golden brown .
#
# remove it from the oven , and turn it out of the pan onto a rack to cool completely .
#
# 24 . store , well-wrapped , at room temperature for 5 days , or freeze for up to 3 months
#
# . <eos> <eos> tips from our bakers <eos> <eos> go : want to make giant buns ? substitute candied red
#
# spice blend ( caraway , less riced sugar ) ( or fennel ) seeds to 1/2 cup almond juice ,

# %%
model.state_dict()
# Out:
# OrderedDict([('encoder.weight',
#               tensor([[ 0.0028, -0.0488,  0.0458,  ...,  0.0854, -0.0508, -0.0885],
#                       [ 0.0334, -0.0620,  0.0995,  ..., -0.0699,  0.0294,  0.0190],
#                       [ 0.0194,  0.0776, -0.0775,  ...,  0.0109, -0.0296, -0.0057],
#                       ...,
#                       [-0.0181,  0.0468, -0.0161,  ..., -0.0976,  0.1331, -0.0938],
#                       [-0.0464, -0.0822, -0.0050,  ..., -0.0435,  0.1616,  0.0049],
#                       [ 0.0399, -0.0633, -0.0185,  ..., -0.0231,  0.1435, -0.0964]],
#                      device='cuda:0')),
#              ('rnn.weight_ih_l0',
#               tensor([[ 0.0332, -0.0626,  0.0374,  ...,  0.0480, -0.0020, -0.0876],
#                       [ 0.0790, -0.0543,  0.0610,  ...,  0.0702,  0.0720,  0.0778],
#                       [-0.1532, -0.1208, -0.0126,  ...,  0.1076, -0.0163,  0.1631],
#                       ...,
#                       [ 0.1267,  0.0683,  0.0443,  ..., -0.0235, -0.0354, -0.0551],
#                       [ 0.0077, -0.1058,  0.1318,  ...,  0.0828, -0.0099,  0.0593],
#                       [ 0.0208, -0.0509,  0.1276,  ..., -0.0131,  0.0011,  0.0237]],
#                      device='cuda:0')),
#              ('rnn.weight_hh_l0',
#               tensor([[ 0.0598,  0.1125,  0.0165,  ...,  0.0546,  0.0276, -0.0267],
#                       [ 0.0409,  0.1039,  0.0163,  ...,  0.0388,  0.0237,  0.0475],
#                       [-0.0660, -0.0079,  0.0223,  ..., -0.0010,  0.0401, -0.0398],
#                       ...,
#                       [-0.0970,  0.0280,  0.0584,  ...,  0.0538, -0.0293,  0.0329],
#                       [-0.0546,  0.0155, -0.0671,  ..., -0.0631, -0.0046, -0.0444],
#                       [-0.0057, -0.0507, -0.0144,  ..., -0.0509, -0.0094,  0.0151]],
#                      device='cuda:0')),
#              ('rnn.bias_ih_l0',
#               tensor([0.0340, 0.0582, 0.0534,  ..., 0.1072, 0.0159, 0.1681], device='cuda:0')),
#              ('rnn.bias_hh_l0',
#               tensor([0.0250, 0.0938, 0.0958,  ..., 0.1279, 0.0004, 0.1495], device='cuda:0')),
#              ('rnn.weight_ih_l1',
#               tensor([[-0.0685, -0.0183, -0.0167,  ...,  0.0342,  0.0814, -0.1054],
#                       [-0.0195, -0.0483, -0.1571,  ...,  0.0166,  0.0805, -0.0387],
#                       [-0.0031,  0.0008, -0.0221,  ..., -0.0465,  0.0674, -0.0297],
#                       ...,
#                       [-0.0656, -0.0165,  0.0465,  ..., -0.0057,  0.0438, -0.0389],
#                       [-0.0092,  0.0196,  0.0057,  ...,  0.0849,  0.0378, -0.0144],
#                       [ 0.0342,  0.0290,  0.0434,  ...,  0.0465, -0.0140,  0.0144]],
#                      device='cuda:0')),
#              ('rnn.weight_hh_l1',
#               tensor([[ 0.0483,  0.0096,  0.0033,  ...,  0.1037, -0.0298, -0.0464],
#                       [-0.1018, -0.0582, -0.0095,  ..., -0.0711,  0.0412,  0.0078],
#                       [ 0.0201, -0.0383,  0.0498,  ..., -0.0560,  0.0274, -0.0007],
#                       ...,
#                       [-0.0633, -0.0138, -0.0136,  ...,  0.0218, -0.0345,  0.0864],
#                       [-0.0198,  0.0375,  0.0347,  ...,  0.0111,  0.0205, -0.0095],
#                       [ 0.0261, -0.0755, -0.0959,  ..., -0.0435,  0.0431, -0.0370]],
#                      device='cuda:0')),
#              ('rnn.bias_ih_l1',
#               tensor([0.0285, 0.0805, 0.0343,  ..., 0.0509, 0.0909, 0.0630], device='cuda:0')),
#              ('rnn.bias_hh_l1',
#               tensor([0.0551, 0.0906, 0.0056,  ..., 0.0672, 0.0687, 0.0709], device='cuda:0')),
#              ('decoder.weight',
#               tensor([[ 0.0028, -0.0488,  0.0458,  ...,  0.0854, -0.0508, -0.0885],
#                       [ 0.0334, -0.0620,  0.0995,  ..., -0.0699,  0.0294,  0.0190],
#                       [ 0.0194,  0.0776, -0.0775,  ...,  0.0109, -0.0296, -0.0057],
#                       ...,
#                       [-0.0181,  0.0468, -0.0161,  ..., -0.0976,  0.1331, -0.0938],
#                       [-0.0464, -0.0822, -0.0050,  ..., -0.0435,  0.1616,  0.0049],
#                       [ 0.0399, -0.0633, -0.0185,  ..., -0.0231,  0.1435, -0.0964]],
#                      device='cuda:0')),
#              ('decoder.bias',
#               tensor([ 0.0414,  0.0205,  0.1578,  ..., -0.1654, -0.1657, -0.1546], device='cuda:0'))])

# %% [markdown]
# ## What do the embeddings look like?

# %%
import scipy
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
len(corpus.dictionary)
# Out:
# 9023

# %%
model.state_dict().keys()
# Out:
# odict_keys(['encoder.weight', 'rnn.weight_ih_l0', 'rnn.weight_hh_l0', 'rnn.bias_ih_l0', 'rnn.bias_hh_l0', 'rnn.weight_ih_l1', 'rnn.weight_hh_l1', 'rnn.bias_ih_l1', 'rnn.bias_hh_l1', 'decoder.weight', 'decoder.bias'])

# %%
model.state_dict()['encoder.weight'].shape
# Out:
# torch.Size([9023, 650])

# %%
embeds = model.state_dict()['encoder.weight']

# %%
np.array(list(corpus.dictionary.word2idx.keys()))
# Out:
# array(['italian', 'hearth', 'bread', ..., 'soda/water', 'communal', '398'],
#       dtype='<U38')

# %%
some_words = ['bank', 'stock', 'bread', 'coffee', 'driving', 'car', 'horse', 'chicken', 'leg', 'good', 'great', 'buy', 'sell']
some_words
# Out:
# ['bank',
#  'stock',
#  'bread',
#  'coffee',
#  'driving',
#  'car',
#  'horse',
#  'chicken',
#  'leg',
#  'good',
#  'great',
#  'buy',
#  'sell']

# %%
some_idxs = [corpus.dictionary.word2idx[word] for word in some_words]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-961341340bf3> in <module>()
# ----> 1 some_idxs = [corpus.dictionary.word2idx[word] for word in some_words]
#
# <ipython-input-31-961341340bf3> in <listcomp>(.0)
# ----> 1 some_idxs = [corpus.dictionary.word2idx[word] for word in some_words]
#
# KeyError: 'bank'

# %%
embeds[0]
# Out:
# tensor([-0.0176,  0.0836,  0.1125, -0.0184, -0.0540,  0.0557,  0.0067,  0.0783,
#          0.0310,  0.0230, -0.1055,  0.0456, -0.0905, -0.1258,  0.0541, -0.0882,
#         -0.0523,  0.0141,  0.0208, -0.0118,  0.0000, -0.1021, -0.0342,  0.0325,
#         -0.0691, -0.1111,  0.0285,  0.1212, -0.0441, -0.0148,  0.0669, -0.0038,
#         -0.0682,  0.0312, -0.0128,  0.0159, -0.0421, -0.1206, -0.0320,  0.0634,
#         -0.0229, -0.0409,  0.0313, -0.0404, -0.0307, -0.0591,  0.0273, -0.0024,
#         -0.0702, -0.0361, -0.0399, -0.0067, -0.0064,  0.0005,  0.0051,  0.0073,
#          0.0382,  0.0252, -0.0164,  0.0938, -0.0375, -0.0030,  0.0981,  0.0110,
#          0.0964,  0.0628, -0.0239, -0.0558,  0.0371,  0.0986,  0.0366,  0.0868,
#         -0.1031, -0.0122,  0.0165,  0.0438, -0.0554, -0.0246, -0.0715, -0.0149,
#         -0.0397,  0.0775,  0.0055, -0.0583,  0.0221, -0.0033, -0.0550, -0.0040,
#          0.0849, -0.1308,  0.0183, -0.0509,  0.0465, -0.0077,  0.0667,  0.1080,
#          0.1427,  0.0512,  0.0609,  0.0325,  0.0903, -0.0875, -0.0574,  0.0316,
#          0.0330, -0.0311, -0.0182, -0.0337, -0.0060,  0.1054,  0.0215,  0.0334,
#         -0.0641,  0.0030,  0.0658, -0.0638, -0.1071, -0.0680, -0.1158,  0.0473,
#          0.1224,  0.1129,  0.0410, -0.0595,  0.0570, -0.0857, -0.0862, -0.0386,
#         -0.0351, -0.0789, -0.0175, -0.1260,  0.0629,  0.0225,  0.0719, -0.0756,
#          0.0546, -0.0030, -0.0282,  0.0808, -0.0699,  0.0128, -0.0995,  0.0609,
#         -0.0653,  0.0314,  0.0199,  0.0914,  0.0528, -0.1226, -0.0405, -0.0448,
#          0.0464, -0.0068,  0.0853,  0.1250,  0.0059, -0.1031, -0.1066,  0.0637,
#          0.0479, -0.0043,  0.1043, -0.1137,  0.0543,  0.0043,  0.0483, -0.0414,
#          0.0574, -0.0975, -0.0804,  0.0366, -0.0070, -0.0898,  0.0324,  0.0391,
#         -0.0091,  0.0857,  0.0263,  0.0947,  0.0832, -0.0102, -0.0394,  0.0831,
#          0.0096, -0.0676,  0.0668, -0.0106, -0.0689,  0.0125,  0.0717, -0.0163,
#          0.0182,  0.0007,  0.0172, -0.0177, -0.0838, -0.0499,  0.0846,  0.0139,
#          0.0087,  0.0323,  0.0235, -0.0303, -0.0105, -0.0512,  0.0972,  0.0879,
#          0.0104,  0.0328,  0.1113, -0.0522,  0.0735,  0.0025, -0.0132,  0.0028,
#         -0.0429, -0.0845, -0.0602, -0.0377,  0.0137, -0.0195,  0.0304,  0.0207,
#          0.0072,  0.0143, -0.0071, -0.0501,  0.0032,  0.0089, -0.0292, -0.0348,
#          0.1182, -0.0236,  0.0881,  0.0208,  0.0055, -0.1107,  0.0912, -0.0224,
#          0.0268, -0.0823,  0.0300, -0.1211, -0.0456, -0.0754, -0.0287, -0.0964,
#         -0.0493, -0.0574, -0.0790,  0.0561, -0.0448,  0.0185, -0.0463,  0.0182,
#         -0.1278, -0.0644, -0.0021,  0.0291, -0.0757,  0.0512,  0.0523, -0.0393,
#         -0.0528, -0.0720, -0.0846, -0.0417, -0.0193,  0.0447,  0.0384, -0.0585,
#         -0.0310, -0.1050, -0.0190,  0.0226,  0.1162, -0.0658, -0.0653, -0.0355,
#         -0.0422,  0.1288, -0.0056,  0.0930, -0.0145,  0.0910, -0.0704, -0.0430,
#          0.0564,  0.0517,  0.1028,  0.0983, -0.0510, -0.1009, -0.0001, -0.0598,
#         -0.0457,  0.0088,  0.0384, -0.0349, -0.0451, -0.0296, -0.0687,  0.0552,
#         -0.0030, -0.1067, -0.0011, -0.0630, -0.0371, -0.0786,  0.0100, -0.0462,
#          0.0780, -0.0207, -0.1257,  0.0138, -0.1087, -0.0336,  0.0280,  0.0106,
#          0.0158, -0.0480,  0.0472,  0.0023, -0.0286, -0.0435, -0.0283,  0.0165,
#         -0.0074, -0.0261, -0.0011,  0.0577, -0.0533, -0.0376,  0.0068, -0.0926,
#          0.0112, -0.0754,  0.0320,  0.1129,  0.0020, -0.1070, -0.0072, -0.0642,
#         -0.0348, -0.0375, -0.0561, -0.0317,  0.1158,  0.0592,  0.1020, -0.0500,
#         -0.0393, -0.0257, -0.0144, -0.0905,  0.0567,  0.0318,  0.0525, -0.0340,
#          0.0864, -0.0802,  0.0302, -0.0375, -0.0151,  0.0112, -0.0228,  0.0464,
#         -0.0385,  0.0030,  0.0337,  0.0682, -0.0549, -0.0876, -0.0315,  0.0348,
#          0.0376, -0.0102,  0.0628,  0.0126,  0.0372,  0.0455, -0.0123,  0.0209,
#          0.0183, -0.1131, -0.0595,  0.0161, -0.0015,  0.0456,  0.0438, -0.0147,
#          0.1010, -0.0849,  0.0368,  0.0390, -0.0274, -0.0026, -0.1191,  0.0811,
#          0.0190,  0.0037,  0.0363, -0.1244, -0.0452, -0.0548,  0.0803, -0.0155,
#         -0.0174, -0.0358,  0.0370, -0.0462, -0.0421, -0.0521, -0.0035,  0.0636,
#         -0.0347, -0.0252, -0.0182,  0.0158, -0.0600, -0.0569,  0.0404, -0.0682,
#         -0.1293, -0.0325, -0.0441, -0.0724, -0.0920,  0.0571, -0.0883,  0.0103,
#         -0.0251,  0.0281,  0.0792, -0.0190, -0.0687,  0.0556,  0.0433, -0.0146,
#         -0.1045,  0.1206,  0.0340, -0.0464, -0.0523,  0.0208, -0.0007,  0.0934,
#         -0.0985,  0.0308, -0.0347,  0.0506, -0.0743,  0.0414, -0.0123,  0.0389,
#         -0.0063, -0.0438,  0.0553, -0.0730,  0.1330,  0.0829, -0.0301, -0.0686,
#          0.0549, -0.0705,  0.0168,  0.0072, -0.0482,  0.0297,  0.0381,  0.0849,
#         -0.0416, -0.0039,  0.0278,  0.0662,  0.0235, -0.0409,  0.0124, -0.1244,
#          0.0520,  0.0231,  0.0819,  0.0041, -0.0776,  0.0718, -0.0185, -0.0801,
#          0.0209, -0.0027,  0.0055,  0.0217,  0.0642, -0.0051,  0.0363,  0.0696,
#         -0.0619,  0.1290, -0.0470, -0.0157, -0.0459, -0.0444,  0.0648, -0.0494,
#         -0.0334, -0.0738, -0.0433, -0.0940, -0.0191, -0.0003,  0.0248, -0.0316,
#         -0.0670,  0.1219,  0.0980,  0.0920,  0.0096,  0.0319, -0.0312, -0.0703,
#          0.0236, -0.0247, -0.0079, -0.0097, -0.0977, -0.1218, -0.0505, -0.0924,
#         -0.0521, -0.0604, -0.0182,  0.0314,  0.0282,  0.0477,  0.0779,  0.0253,
#         -0.0480,  0.0225,  0.0037,  0.0086,  0.0253,  0.0293,  0.0485, -0.0471,
#         -0.0656,  0.0818, -0.0484,  0.0253,  0.0225, -0.0503,  0.0508, -0.0434,
#          0.0010,  0.1357, -0.0234,  0.0319, -0.0942, -0.0832, -0.0375, -0.0167,
#          0.0596, -0.0131, -0.0154,  0.0088,  0.0627, -0.0672, -0.0167,  0.0874,
#          0.0346,  0.1305,  0.0246,  0.0454,  0.0120,  0.0267, -0.0445,  0.0799,
#          0.0132,  0.0777, -0.1098,  0.1095,  0.0797, -0.0495, -0.0483, -0.1083,
#         -0.0085, -0.0345, -0.0103,  0.0348, -0.0569,  0.0359, -0.1099,  0.0074,
#          0.0080,  0.1091, -0.1174,  0.0465,  0.0353, -0.0041,  0.0747, -0.0715,
#         -0.0009,  0.0306,  0.0876, -0.0394,  0.0013, -0.0696,  0.0552,  0.0546,
#          0.0020, -0.0755,  0.0940,  0.0127, -0.0351, -0.0205, -0.0519, -0.0194,
#         -0.0641, -0.0090,  0.0583,  0.0416, -0.0334,  0.0690,  0.0506, -0.0734,
#         -0.0481, -0.0076,  0.0358,  0.0285, -0.1276,  0.0571,  0.0400,  0.0030,
#         -0.0861,  0.0111,  0.0755,  0.0208,  0.0782, -0.0180,  0.0844,  0.0598,
#          0.0581, -0.0078, -0.0277, -0.0097,  0.0410, -0.0331,  0.1378, -0.0576,
#          0.0625,  0.0272], device='cuda:0')

# %%
print(embeds[some_idxs].shape)
np.array(embeds[some_idxs])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-b731014936c7> in <module>()
# ----> 1 print(embeds[some_idxs].shape)
#       2 np.array(embeds[some_idxs])
#
# NameError: name 'some_idxs' is not defined

# %%
tsne = TSNE(n_components=2, random_state=123)
#np.set_printoptions(suppress=True)
#Y = tsne.fit_transform(np.array(embeds[some_idxs]))
idxs = np.random.choice(range(embeds.shape[0]), 200, replace=False)
labels = [corpus.dictionary.idx2word[_] for _ in idxs]
Y = tsne.fit_transform(np.array(embeds[idxs]))
#Y = tsne.fit_transform(np.array(embeds))

# %%
x_coords = Y[:, 0]
y_coords = Y[:, 1]
# display scatter plot
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
plt.scatter(x_coords, y_coords)

for label, x, y in zip(labels, x_coords, y_coords):
    plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points')
plt.xlim(x_coords.min()+0.00005, x_coords.max()+0.00005)
plt.ylim(y_coords.min()+0.00005, y_coords.max()+0.00005)
plt.show()

# %% [markdown]
# Pretty interesting, seems to have learned this corpus a bit better
